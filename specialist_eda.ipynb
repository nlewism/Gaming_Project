# %%
from ydata_profiling import ProfileReport as pr
import dtale

# %%
import re
import pandas as pd

# %%
apex = pd.read_csv('/Users/natalielewis/Desktop/Ironhack/Gaming_Project/Final-Project/apex_legends.csv')
apex.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
bf_2042 = pd.read_csv('/Users/natalielewis/Desktop/Ironhack/Gaming_Project/Final-Project/bf2042_specialists.csv')

# %%
apex = pd.read_csv('/Users/natalielewis/Desktop/Ironhack/Gaming_Project/Final-Project/apex_legends.csv')
bf_2042 = pd.read_csv('/Users/natalielewis/Desktop/Ironhack/Gaming_Project/Final-Project/bf2042_specialists.csv')
overwatch = pd.read_csv('/Users/natalielewis/Desktop/Ironhack/Gaming_Project/Final-Project/overwatch_heroes.csv')
r6_attackers = pd.read_csv('/Users/natalielewis/Desktop/Ironhack/Gaming_Project/Final-Project/r6_attackers.csv')
r6_defenders = pd.read_csv('/Users/natalielewis/Desktop/Ironhack/Gaming_Project/Final-Project/r6_defenders.csv')
apex.drop(['Unnamed: 0'],axis=1,inplace=True)
bf_2042.drop(['Unnamed: 0'],axis=1,inplace=True)
overwatch.drop(['Unnamed: 0'],axis=1,inplace=True)
r6_attackers.drop(['Unnamed: 0'],axis=1,inplace=True)
r6_defenders.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
pr(apex)
# Out:
# ...
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  3.31it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.6.4&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-02-01 20:10:35.477878&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# #### Changing row contents

# %%
bf_2042.loc[8,'Specialist Specialty']='SUPPORT'

# %%
bf_2042
# Out:
#     Unnamed: 0            Specialist Name Specialist Specialty  \
# 0            0  SANTIAGO "DOZER" ESPINOZA              ASSAULT
# 1            1                JI-SOO PAIK                RECON
# 2            2   WIKUS "CASPER" VAN DAELE                RECON
# 3            3           CHARLIE CRAWFORD             ENGINEER
# 4            4               RASHEED ZAIN              ASSAULT
# 5            5              CAMILA BLASCO                RECON
# 6            6    PYOTR "BORIS" GUSKOVSKY             ENGINEER
# 7            7                MARIA FALCK              SUPPORT
# 8            8  CONSTANTIN "ANGEL" ANGHEL              SUPPORT
# 9            9                  NAVIN RAO                RECON
# 10          10                EWELINA LIS             ENGINEER
# 11          11      KIMBLE “IRISH” GRAVES              SUPPORT
# 12          12             WEBSTER MACKAY              ASSAULT
# 13          13     EMMA "SUNDANCE" ROSIER              ASSAULT
#
# ...

# %% [markdown]
# Define Specialty Parameters
# - Add columns to R6 attackers & defenders  -- DONE !
# - Clean Overwatch Columns and define specialty -- DONE !
# - Clean APEX Columns and define specialty -- DONE !
#
# Define Attackers & Defenders
# - Add the columns to OVERWATCH -- DONE!
# - Add the columns to BF2042 -- DONE !
# - Add the columns to APEX -- DONE !
#
# Player Difficulty
# - Add player difficulty to BF2042 -- DONE !
# - Add player difficulty to APEX -- DONE !
# - Add player difficulty to OVERWATCH -- DONE!
#
# Special Skills
# - Will be displayed as facts

# %% [markdown]
# # Let the Categorizing Begin

# %%
r6_attackers
# Out:
#    Operator Name  Health  Speed  Difficulty  Breach  Intel  Anti-Gadget  \
# 0            Ram       3      1           2       1      0            0
# 1          Brava       1      3           3       0      1            1
# 2           Grim       1      3           1       0      0            0
# 3           Sens       1      3           2       0      0            0
# 4            Osa       3      1           2       0      1            0
# 5         Flores       2      2           2       0      1            1
# 6           Zero       1      3           0       0      1            1
# 7            Ace       2      2           1       1      0            1
# 8           Iana       2      2           1       0      1            0
# 9           Kali       2      2           2       0      0            1
# 10         Amaru       2      2           2       0      0            0
# 11          Nøkk       2      2           3       0      0            0
# ...

# %%
r6_attackers = r6_attackers.apply(lambda x: x.str.title() if x.dtype == 'object' else x)
r6_attackers.columns = [col.title() for col in r6_attackers.columns]

# %%
difficulty = r6_attackers.groupby('Difficulty')
difficulty_1 = difficulty.get_group(1)
difficulty_2 = difficulty.get_group(2)
difficulty_3 = difficulty.get_group(3)

# %%
difficulty_1
# Out:
#    Operator Name  Health  Speed  Difficulty    Operator Unique Ability  \
# 0            Ram       3      1           2        Bu-Gi Auto Breacher
# 4            Osa       3      1           2       Talon-8 Clear Shield
# 12      Gridlock       3      1           1              Trax Stingers
# 18         Zofia       3      1           1              Ks79 Lifeline
# 25        Sledge       3      1           1  Tactical Breaching Hammer
# 26      Thatcher       3      1           1                Emp Grenade
# 29      Montagne       3      1           3              Le Roc Shield
# 33          Fuze       3      1           1             Cluster Charge
#
#                            Unique Ability Description      Type Specialty
# 0   Very Little Can Stand In The Way Of The New Bu...  Attacker   Assault
# 4   The Transparent And Bulletproof Talon-8 Shield...  Attacker     Recon
# 12  Trax Stingers' Design Is A Portable Version Th...  Attacker   Support
# ...

# %%
health = r6_attackers.groupby('Health')
health_1 = health.get_group(1)
health_2 = health.get_group(2)
health_3 = health.get_group(3)

# %%
health_3
# Out:
#    Operator Name  Health  Speed  Difficulty    Operator Unique Ability  \
# 0            Ram       3      1           2        Bu-Gi Auto Breacher
# 4            Osa       3      1           2       Talon-8 Clear Shield
# 12      Gridlock       3      1           1              Trax Stingers
# 18         Zofia       3      1           1              Ks79 Lifeline
# 25        Sledge       3      1           1  Tactical Breaching Hammer
# 26      Thatcher       3      1           1                Emp Grenade
# 29      Montagne       3      1           3              Le Roc Shield
# 33          Fuze       3      1           1             Cluster Charge
#
#                            Unique Ability Description      Type Specialty
# 0   Very Little Can Stand In The Way Of The New Bu...  Attacker   Assault
# 4   The Transparent And Bulletproof Talon-8 Shield...  Attacker     Recon
# 12  Trax Stingers' Design Is A Portable Version Th...  Attacker   Support
# ...

# %%
speed = r6_attackers.groupby('Speed')
speed_1 = speed.get_group(1)
speed_2 = speed.get_group(2)
speed_3 = speed.get_group(3)

# %%
speed_3
# Out:
#    Operator Name  Health  Speed  Difficulty  Operator Unique Ability  \
# 1          Brava       1      3           3             Kludge Drone
# 2           Grim       1      3           1      Kawan Hive Launcher
# 3           Sens       1      3           2  R.O.U. Projector System
# 6           Zero       1      3           0           Argus Launcher
# 14      Maverick       1      3           2          Breaching Torch
# 17      Dokkaebi       1      3           2               Logic Bomb
# 21        Hibana       1      3           1                 X-Kairos
# 22       Capitão       1      3           2        Tactical Crossbow
# 27           Ash       1      3           2         Breaching Rounds
# 32            Iq       1      3           3     Electronics Detector
# 34          Glaz       1      3           2               Flip Sight
#
#                            Unique Ability Description      Type Specialty
# ...

# %%
specialty_mapping = {
    'Breach': 'Assault',
    'Intel': 'Recon',
    'Anti-Gadget': 'Engineer',
    'Front Line': 'Assault',
    'Map Control': 'Support',
    'Support': 'Support'
}

# %%
# Create a new column by finding the column name with the highest value (1) for each row
r6_attackers['Specialty'] = r6_attackers[['Breach', 'Intel', 'Anti-Gadget', 'Front Line', 'Map Control', 'Support']].idxmax(axis=1)
r6_attackers['Specialty'] = r6_attackers['Specialty'].map(specialty_mapping)

# %%
r6_attackers.drop(columns=['Breach', 'Intel', 'Anti-Gadget', 'Front Line', 'Map Control', 'Support'], inplace=True)

# %%
r6_attackers
# Out:
#    Operator Name  Health  Speed  Difficulty    Operator Unique Ability  \
# 0            Ram       3      1           2        Bu-Gi Auto Breacher
# 1          Brava       1      3           3               Kludge Drone
# 2           Grim       1      3           1        Kawan Hive Launcher
# 3           Sens       1      3           2    R.O.U. Projector System
# 4            Osa       3      1           2       Talon-8 Clear Shield
# 5         Flores       2      2           2          Rce-Ratero Charge
# 6           Zero       1      3           0             Argus Launcher
# 7            Ace       2      2           1   S.E.L.M.A. Aqua Breacher
# 8           Iana       2      2           1          Gemini Replicator
# 9           Kali       2      2           2         Lv Explosive Lance
# 10         Amaru       2      2           2                 Garra Hook
# 11          Nøkk       2      2           3     Hel Presence Reduction
# ...

# %% [markdown]
# #### Working on Defenders

# %%
r6_defenders = r6_defenders.apply(lambda x: x.str.title() if x.dtype == 'object' else x)
r6_defenders.columns = [col.title() for col in r6_defenders.columns]

# %%
difficulty = r6_defenders.groupby('Difficulty')
difficulty_1 = difficulty.get_group(1)
difficulty_2 = difficulty.get_group(2)
difficulty_3 = difficulty.get_group(3)

health = r6_defenders.groupby('Health')
health_1 = health.get_group(1)
health_2 = health.get_group(2)
health_3 = health.get_group(3)

speed = r6_defenders.groupby('Speed')
speed_1 = speed.get_group(1)
speed_2 = speed.get_group(2)
speed_3 = speed.get_group(3)

# %%
difficulty_1
# Out:
#    Operator Name  Health  Speed  Difficulty  Anti-Entry  Anti-Gadget  Trapper  \
# 4          Thorn       2      2           1           1            0        1
# 5    Thunderbird       2      2           1           0            0        0
# 7         Melusi       3      1           1           0            0        0
# 18           Ela       2      2           1           0            0        1
# 19        Lesion       2      2           1           1            0        1
# 24         Frost       2      2           1           1            0        1
# 25          Mute       3      1           1           0            1        0
# 29           Doc       3      1           1           0            0        0
# 30          Rook       3      1           1           0            0        0
# 32        Bandit       1      3           1           1            1        0
# 33      Tachanka       3      1           1           1            0        0
# ...

# %%
specialty_mapping = {
    'Anti-Entry': 'Assault',
    'Intel': 'Recon',
    'Anti-Gadget': 'Engineer',
    'Trapper': 'Assault',
    'Crowd Control': 'Support',
    'Support': 'Support'
}

# %%
# Create a new column by finding the column name with the highest value (1) for each row
r6_defenders['Specialty'] = r6_defenders[['Anti-Entry', 'Intel', 'Anti-Gadget', 'Trapper', 'Crowd Control', 'Support']].idxmax(axis=1)
r6_defenders['Specialty'] = r6_defenders['Specialty'].map(specialty_mapping)

r6_defenders.drop(columns=['Anti-Entry', 'Intel', 'Anti-Gadget', 'Trapper', 'Crowd Control', 'Support'], inplace=True)

# %%
r6_defenders
# Out:
#    Operator Name  Health  Speed  Difficulty Operator Unique Ability  \
# 0        Tubarão       2      2           0           Zoto Canister
# 1         Fenrir       2      2           3       F-Natt Dread Mine
# 2          Solis       2      2           3  Spec-Io Electro-Sensor
# 3          Azami       2      2           3            Kiba Barrier
# 4          Thorn       2      2           1        Razorbloom Shell
# 5    Thunderbird       2      2           1            Kóna Station
# 6          Aruni       3      1           2              Surya Gate
# 7         Melusi       3      1           1   Banshee Sonic Defense
# 8           Oryx       2      2           2              Remah Dash
# 9          Wamai       2      2           2          Mag-Net System
# 10          Goyo       2      2           2         Volcán Canister
# 11        Warden       3      1           2    Glance Smart Glasses
# 12        Mozzie       2      2           2           Pest Launcher
# ...

# %%
r6_operators = pd.concat([r6_attackers,r6_defenders])

# %%
r6_operators
# Out:
#    Operator Name  Health  Speed  Difficulty  Operator Unique Ability  \
# 0            Ram       3      1           2      Bu-Gi Auto Breacher
# 1          Brava       1      3           3             Kludge Drone
# 2           Grim       1      3           1      Kawan Hive Launcher
# 3           Sens       1      3           2  R.O.U. Projector System
# 4            Osa       3      1           2     Talon-8 Clear Shield
# ..           ...     ...    ...         ...                      ...
# 30          Rook       3      1           1               Armor Pack
# 31         Jäger       2      2           2    Active Defense System
# 32        Bandit       1      3           1               Shock Wire
# 33      Tachanka       3      1           1        Shumikha Launcher
# 34        Kapkan       2      2           1      Entry Denial Device
#
#                            Unique Ability Description      Type Specialty
# ...

# %% [markdown]
# #### Export to Tableau

# %%
r6_operators.to_csv('r6_operators.csv')

# %% [markdown]
# ### Specialty Parameters for Overwatch

# %%
overwatch
# Out:
#         Hero Name Hero Specialty                      Ability 1  \
# 0           LÚCIO        Support                SONIC_AMPLIFIER
# 1      WIDOWMAKER         Damage                   WIDOW'S_KISS
# 2        ZENYATTA        Support             ORB_OF_DESTRUCTION
# 3            ECHO         Damage                       TRI-SHOT
# 4         SOJOURN         Damage                        RAILGUN
# 5           MAUGA           Tank                        OVERRUN
# 6             MEI         Damage            ENDOTHERMIC_BLASTER
# 7           ZARYA           Tank                PARTICLE_CANNON
# 8        BRIGITTE        Support                   ROCKET_FLAIL
# 9           HANZO         Damage                      STORM_BOW
# 10         REAPER         Damage              HELLFIRE_SHOTGUNS
# 11          ORISA           Tank        AUGMENTED_FUSION_DRIVER
# 12         ILLARI        Support                    SOLAR_RIFLE
# 13     LIFEWEAVER        Support                HEALING_BLOSSOM
# ...

# %%
specialty = {
    'Tank': 'Engineer',
    'Damage': 'Assault',
    'Support': 'Support'
}

# %%
overwatch['Hero Specialty'] = overwatch['Hero Specialty'].replace(specialty)

# %%
overwatch
# Out:
#         Hero Name Hero Specialty                      Ability 1  \
# 0           LÚCIO        Support                SONIC_AMPLIFIER
# 1      WIDOWMAKER        Assault                   WIDOW'S_KISS
# 2        ZENYATTA        Support             ORB_OF_DESTRUCTION
# 3            ECHO        Assault                       TRI-SHOT
# 4         SOJOURN        Assault                        RAILGUN
# 5           MAUGA       Engineer                        OVERRUN
# 6             MEI        Assault            ENDOTHERMIC_BLASTER
# 7           ZARYA       Engineer                PARTICLE_CANNON
# 8        BRIGITTE        Support                   ROCKET_FLAIL
# 9           HANZO        Assault                      STORM_BOW
# 10         REAPER        Assault              HELLFIRE_SHOTGUNS
# 11          ORISA       Engineer        AUGMENTED_FUSION_DRIVER
# 12         ILLARI        Support                    SOLAR_RIFLE
# 13     LIFEWEAVER        Support                HEALING_BLOSSOM
# ...

# %%
overwatch['Difficulty'] = None

# %%
overwatch.loc[0, 'Difficulty'] = 1 
overwatch.loc[1, 'Difficulty'] = 2  
overwatch.loc[2, 'Difficulty'] = 3  
overwatch.loc[3, 'Difficulty'] = 2 
overwatch.loc[4, 'Difficulty'] = 3  
overwatch.loc[5, 'Difficulty'] = 2 
overwatch.loc[6, 'Difficulty'] = 3  
overwatch.loc[7, 'Difficulty'] = 3  
overwatch.loc[8, 'Difficulty'] = 1  
overwatch.loc[9, 'Difficulty'] = 3  
overwatch.loc[10, 'Difficulty'] = 1  
overwatch.loc[11, 'Difficulty'] = 1  
overwatch.loc[12, 'Difficulty'] = 3  
overwatch.loc[13, 'Difficulty'] = 1  
overwatch.loc[14, 'Difficulty'] = 3  
overwatch.loc[15, 'Difficulty'] = 2  
overwatch.loc[16, 'Difficulty'] = 3  
overwatch.loc[17, 'Difficulty'] = 2  
overwatch.loc[18, 'Difficulty'] = 3  
overwatch.loc[19, 'Difficulty'] = 3  
overwatch.loc[20, 'Difficulty'] = 1  
overwatch.loc[21, 'Difficulty'] = 2  
overwatch.loc[22, 'Difficulty'] = 1 
overwatch.loc[23, 'Difficulty'] = 3  
overwatch.loc[24, 'Difficulty'] = 3 
overwatch.loc[25, 'Difficulty'] = 1  
overwatch.loc[26, 'Difficulty'] = 3  
overwatch.loc[27, 'Difficulty'] = 3 
overwatch.loc[28, 'Difficulty'] = 1  
overwatch.loc[29, 'Difficulty'] = 1  
overwatch.loc[30, 'Difficulty'] = 2  
overwatch.loc[31, 'Difficulty'] = 2 
overwatch.loc[32, 'Difficulty'] = 2  
overwatch.loc[33, 'Difficulty'] = 2  
overwatch.loc[34, 'Difficulty'] = 1  
overwatch.loc[35, 'Difficulty'] = 3
overwatch.loc[36, 'Difficulty'] = 1  
overwatch.loc[37, 'Difficulty'] = 2  
overwatch.loc[38, 'Difficulty'] = 2

# %%
# Define a function to determine the role based on the values in the 'Specialty' column
def determine_role(specialty):
    if specialty == 'Support':
        return 'Defender'
    elif specialty in ['Assault', 'Engineer']:
        return 'Attacker'
    else:
        return 'Unknown'

# %%
# Create a new column 'Role' by applying the determine_role function to the 'Specialty' column
overwatch['Role'] = overwatch['Hero Specialty'].apply(determine_role)

# %%
overwatch
# Out:
#         Hero Name Hero Specialty                      Ability 1  \
# 0           LÚCIO        Support                SONIC_AMPLIFIER
# 1      WIDOWMAKER        Assault                   WIDOW'S_KISS
# 2        ZENYATTA        Support             ORB_OF_DESTRUCTION
# 3            ECHO        Assault                       TRI-SHOT
# 4         SOJOURN        Assault                        RAILGUN
# 5           MAUGA       Engineer                        OVERRUN
# 6             MEI        Assault            ENDOTHERMIC_BLASTER
# 7           ZARYA       Engineer                PARTICLE_CANNON
# 8        BRIGITTE        Support                   ROCKET_FLAIL
# 9           HANZO        Assault                      STORM_BOW
# 10         REAPER        Assault              HELLFIRE_SHOTGUNS
# 11          ORISA       Engineer        AUGMENTED_FUSION_DRIVER
# 12         ILLARI        Support                    SOLAR_RIFLE
# 13     LIFEWEAVER        Support                HEALING_BLOSSOM
# ...

# %%
overwatch.to_csv('overwatch_heroes.csv')

# %% [markdown]
# ### APEX LEGENDS

# %%
apex
# Out:
#    legend_name legend_specialty        tactical_ability  \
# 0    BANGALORE          Assault          Smoke Launcher
# 1         LOBA          Support   Burglar’S Best Friend
# 2     LIFELINE          Support       D.O.C. Heal Drone
# 3   PATHFINDER          Assault          Grappling Hook
# 4   BLOODHOUND            Recon    Eye Of The Allfather
# 5      HORIZON          Assault            Gravity Lift
# 6   MAD MAGGIE          Assault              Riot Drill
# 7         FUSE          Assault         Knuckle Cluster
# 8      RAMPART         Engineer             Amped Cover
# 9      WATTSON         Engineer      Perimeter Security
# 10   BALLISTIC          Assault                Whistler
# 11        SEER            Recon      Focus Of Attention
# 12     CAUSTIC         Engineer            Nox Gas Trap
# 13     VANTAGE            Recon         Echo Relocation
# 14      CRYPTO            Recon      Surveillance Drone
# 15   NEWCASTLE          Support           Mobile Shield
# ...

# %%
apex.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
# Define a function to determine the role based on the values in the 'Specialty' column
def determine_role(specialty):
    if specialty in ['Recon','Support','Controller']:
        return 'Defender'
    elif specialty in ['Assault', 'Skirmisher']:
        return 'Attacker'
    else:
        return 'Unknown'

# %%
apex['Role'] = apex['legend_specialty'].apply(determine_role)

# %%
# Specialty 
legend_specialties = {
    'Recon': 'Recon',
    'Assault': 'Assault',
    'Support': 'Support',
    'Controller':'Engineer',
    'Skirmisher':'Assault',
}

# %%
apex['legend_specialty'] = apex['legend_specialty'].replace(legend_specialties)

# %%
apex['Difficulty'] = None

# %%
apex.loc[0, 'Difficulty'] = 1 
apex.loc[1, 'Difficulty'] = 2 
apex.loc[2, 'Difficulty'] = 2 
apex.loc[3, 'Difficulty'] = 3 
apex.loc[4, 'Difficulty'] = 1 
apex.loc[5, 'Difficulty'] = 3 
apex.loc[6, 'Difficulty'] = 2
apex.loc[7, 'Difficulty'] = 1 
apex.loc[8, 'Difficulty'] = 1 
apex.loc[9, 'Difficulty'] = 3 
apex.loc[10, 'Difficulty'] = 1 
apex.loc[11, 'Difficulty'] = 2   
apex.loc[12, 'Difficulty'] = 2   
apex.loc[13, 'Difficulty'] = 3 
apex.loc[14, 'Difficulty'] = 3 
apex.loc[15, 'Difficulty'] = 3 
apex.loc[16, 'Difficulty'] = 3 
apex.loc[17, 'Difficulty'] = 3 
apex.loc[18, 'Difficulty'] = 1 
apex.loc[19, 'Difficulty'] = 3 
apex.loc[20, 'Difficulty'] = 3 
apex.loc[21, 'Difficulty'] = 3 
apex.loc[22, 'Difficulty'] = 1 
apex.loc[23, 'Difficulty'] = 3

# %%
apex.to_csv('apex_legends_ranked.csv')

# %%
apex
# Out:
#    legend_name legend_specialty        tactical_ability  \
# 0    BANGALORE          Assault          Smoke Launcher
# 1         LOBA          Support   Burglar’S Best Friend
# 2     LIFELINE          Support       D.O.C. Heal Drone
# 3   PATHFINDER          Assault          Grappling Hook
# 4   BLOODHOUND            Recon    Eye Of The Allfather
# 5      HORIZON          Assault            Gravity Lift
# 6   MAD MAGGIE          Assault              Riot Drill
# 7         FUSE          Assault         Knuckle Cluster
# 8      RAMPART         Engineer             Amped Cover
# 9      WATTSON         Engineer      Perimeter Security
# 10   BALLISTIC          Assault                Whistler
# 11        SEER            Recon      Focus Of Attention
# 12     CAUSTIC         Engineer            Nox Gas Trap
# 13     VANTAGE            Recon         Echo Relocation
# 14      CRYPTO            Recon      Surveillance Drone
# 15   NEWCASTLE          Support           Mobile Shield
# ...

# %% [markdown]
# ### Heading into the Battlefield

# %%
bf_2042
# Out:
#     Unnamed: 0            Specialist Name Specialist Specialty  \
# 0            0  SANTIAGO "DOZER" ESPINOZA              ASSAULT
# 1            1                JI-SOO PAIK                RECON
# 2            2   WIKUS "CASPER" VAN DAELE                RECON
# 3            3           CHARLIE CRAWFORD             ENGINEER
# 4            4               RASHEED ZAIN              ASSAULT
# 5            5              CAMILA BLASCO                RECON
# 6            6    PYOTR "BORIS" GUSKOVSKY             ENGINEER
# 7            7                MARIA FALCK              SUPPORT
# 8            8  CONSTANTIN "ANGEL" ANGHEL              SOUTIEN
# 9            9                  NAVIN RAO                RECON
# 10          10                EWELINA LIS             ENGINEER
# 11          11      KIMBLE “IRISH” GRAVES              SUPPORT
# 12          12             WEBSTER MACKAY              ASSAULT
# 13          13     EMMA "SUNDANCE" ROSIER              ASSAULT
#
# ...

# %%
bf_2042.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
bf_2042.loc[8,'Specialist Specialty']='SUPPORT'

# %%
# Define a function to determine the role based on the values in the 'Specialty' column
def determine_role(specialty):
    if specialty in ['ENGINEER','SUPPORT']:
        return 'Defender'
    elif specialty in ['ASSAULT', 'RECON']:
        return 'Attacker'
    else:
        return 'Unknown'

# %%
bf_2042['Role'] = bf_2042['Specialist Specialty'].apply(determine_role)

# %%
bf_2042['Difficulty'] = None

# %%
bf_2042.loc[0, 'Difficulty'] = 1 
bf_2042.loc[1, 'Difficulty'] = 3
bf_2042.loc[2, 'Difficulty'] = 2 
bf_2042.loc[3, 'Difficulty'] = 1 
bf_2042.loc[4, 'Difficulty'] = 1 
bf_2042.loc[5, 'Difficulty'] = 3
bf_2042.loc[6, 'Difficulty'] = 2 
bf_2042.loc[7, 'Difficulty'] = 3
bf_2042.loc[8, 'Difficulty'] = 1 
bf_2042.loc[9, 'Difficulty'] = 2 
bf_2042.loc[10, 'Difficulty'] = 3 
bf_2042.loc[11, 'Difficulty'] = 2 
bf_2042.loc[12, 'Difficulty'] = 1 
bf_2042.loc[13, 'Difficulty'] = 1

# %%
bf_2042

# %% [markdown]
# # Model Training

# %%
df = pd.read_csv('/Users/natalielewis/Desktop/Ironhack/Gaming_Project/player_list_1.csv', thousands=',')

# %%
df
# Out:
#     Unnamed: 0             name  GENERAL - COMBAT.PVPAccuracy  \
# 0            0       zFanfarrao                         48.10
# 1            1    x.C.H.R.I.S.x                         36.80
# 2            2     ZootvonKlaus                         38.40
# 3            3         x ranl x                         37.70
# 4            4    B U T C H E R                         36.30
# 5            5       pwnwallius                         39.10
# 6            6          FANG799                         34.20
# 7            7        LV17Luwis                         44.90
# 8            8     Blood Artist                         48.40
# 9            9           NoboIe                         45.10
# 10          10           Bembah                         46.10
# 11          11          lPhobos                         42.10
# 12          12   Thatasianguy12                         32.50
# 13          13      HASSAN-TOMY                         46.00
# ...

# %% [markdown]
# - Main KPI'S
# - Main Descriptions
# - Evidence of the data

# %%
from sklearn.preprocessing import StandardScaler

# %%
df_recommender = df[['GENERAL - COMBAT.PVPAccuracy','GENERAL - COMBAT.PVPMeleeKills','GENERAL - COMBAT.PVPBlindKills']]

# %%
scaler = StandardScaler()
xscaled = scaler.fit_transform(df_recommender)

# %%
to_predict = df_recommender.iloc[[0]]

# %%
to_predict_scaled = scaler.transform(to_predict)

# %%
from scipy.spatial.distance import cdist

# %%
pd.DataFrame(cdist(xscaled,to_predict_scaled),index=df['name'],columns=['Distance']).sort_values('Distance').head()
# Out:
#                  Distance
# name
# zFanfarrao       0.000000
# OpaHildegard.VO  0.695041
# LV17Luwis        0.818842
# NIRVlA           1.169252
# Blood Artist     1.182762

# %% [markdown]
# ## Model Training with Specialist

# %%
bf_2042
# Out:
#               Specialist Name Specialist Specialty  \
# 0   SANTIAGO "DOZER" ESPINOZA              ASSAULT
# 1                 JI-SOO PAIK                RECON
# 2    WIKUS "CASPER" VAN DAELE                RECON
# 3            CHARLIE CRAWFORD             ENGINEER
# 4                RASHEED ZAIN              ASSAULT
# 5               CAMILA BLASCO                RECON
# 6     PYOTR "BORIS" GUSKOVSKY             ENGINEER
# 7                 MARIA FALCK              SUPPORT
# 8   CONSTANTIN "ANGEL" ANGHEL              SUPPORT
# 9                   NAVIN RAO                RECON
# 10                EWELINA LIS             ENGINEER
# 11      KIMBLE “IRISH” GRAVES              SUPPORT
# 12             WEBSTER MACKAY              ASSAULT
# 13     EMMA "SUNDANCE" ROSIER              ASSAULT
#
#            Specialist Special Skill 1 Specialist Special Skill 2      Role  \
# 0              SOB-8 Ballistic Shield            Blast Resistant  Attacker
# ...

# %%
bf_2042_recommender = bf_2042[['Specialist Specialty','Role','Difficulty']]

# %% [markdown]
# ### One Hot Encoding Needed

# %%
columns_to_encode = ['Specialist Specialty', 'Role', 'Difficulty']

# %%
encoded_df = pd.get_dummies(bf_2042[columns_to_encode])

# %%
final_df = pd.concat([bf_2042, encoded_df], axis=1)

# %%
final_df.drop(columns=columns_to_encode, inplace=True)
final_df
# Out:
#               Specialist Name         Specialist Special Skill 1  \
# 0   SANTIAGO "DOZER" ESPINOZA             SOB-8 Ballistic Shield
# 1                 JI-SOO PAIK                      EMG-X Scanner
# 2    WIKUS "CASPER" VAN DAELE                   OV-P Recon Drone
# 3            CHARLIE CRAWFORD  Mounted Vulcan Stationary Minigun
# 4                RASHEED ZAIN           XM370A Airburst Launcher
# 5               CAMILA BLASCO             X6-Infiltration Device
# 6     PYOTR "BORIS" GUSKOVSKY                   SG-36 Sentry Gun
# 7                 MARIA FALCK                 S21 Syrette Pistol
# 8   CONSTANTIN "ANGEL" ANGHEL                      Loadout Crate
# 9                   NAVIN RAO                Cyber Warfare Suite
# 10                EWELINA LIS                           G-84 TGM
# 11      KIMBLE “IRISH” GRAVES               Fortification System
# 12             WEBSTER MACKAY                     Grappling Hook
# ...

# %% [markdown]
# ### Redoing the training

# %%
bf_2042_recommender = final_df[['Specialist Specialty_ASSAULT','Specialist Specialty_ENGINEER','Specialist Specialty_RECON','Specialist Specialty_SUPPORT', 'Role_Attacker','Role_Defender','Difficulty_1', 'Difficulty_2', 'Difficulty_3']]

# %%
scaler = StandardScaler()
xscaled = scaler.fit_transform(bf_2042_recommender)

# %%
to_predict = bf_2042_recommender.iloc[[0]]

# %%
to_predict_scaled = scaler.transform(to_predict)

# %%
from scipy.spatial.distance import cdist

# %%
pd.DataFrame(cdist(xscaled,to_predict_scaled),index=final_df['Specialist Name'],columns=['Distance']).sort_values('Distance').head()
# Out:
#                            Distance
# Specialist Name
# SANTIAGO "DOZER" ESPINOZA  0.000000
# RASHEED ZAIN               0.000000
# WEBSTER MACKAY             0.000000
# EMMA "SUNDANCE" ROSIER     0.000000
# JI-SOO PAIK                4.333974

# %% [markdown]
# ### Let's bring another game to the table

# %%
apex
# Out:
#    legend_name legend_specialty        tactical_ability  \
# 0    BANGALORE          Assault          Smoke Launcher
# 1         LOBA          Support   Burglar’S Best Friend
# 2     LIFELINE          Support       D.O.C. Heal Drone
# 3   PATHFINDER          Assault          Grappling Hook
# 4   BLOODHOUND            Recon    Eye Of The Allfather
# 5      HORIZON          Assault            Gravity Lift
# 6   MAD MAGGIE          Assault              Riot Drill
# 7         FUSE          Assault         Knuckle Cluster
# 8      RAMPART         Engineer             Amped Cover
# 9      WATTSON         Engineer      Perimeter Security
# 10   BALLISTIC          Assault                Whistler
# 11        SEER            Recon      Focus Of Attention
# 12     CAUSTIC         Engineer            Nox Gas Trap
# 13     VANTAGE            Recon         Echo Relocation
# 14      CRYPTO            Recon      Surveillance Drone
# 15   NEWCASTLE          Support           Mobile Shield
# ...

# %%
apex_columns_to_encode = ['legend_specialty','Role','Difficulty']

# %%
apex_encoded_df = pd.get_dummies(apex[apex_columns_to_encode])

# %%
final_apex = pd.concat([apex, apex_encoded_df], axis=1)

# %%
final_apex.drop(columns=apex_columns_to_encode,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 final_apex.drop(columns=apex_columns_to_encode,inplace=True)
#
# File ~/Desktop/Ironhack/Gaming_Project/Final-Project/lib/python3.9/site-packages/pandas/core/frame.py:5568, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5420 def drop(
#    5421     self,
#    5422     labels: IndexLabel | None = None,
#    (...)
#    5429     errors: IgnoreRaise = "raise",
#    5430 ) -> DataFrame | None:
#    5431     """
#    5432     Drop specified labels from rows or columns.
#    5433
#    (...)
#    5566             weight  1.0     0.8
#    5567     """
# -> 5568     return super().drop(
#    5569         labels=labels,
#    5570         axis=axis,
#    5571         index=index,
#    5572         columns=columns,
#    5573         level=level,
# ...

# %%
standard_columns = {
    'legend_name':'name',
    'legend_specialty_Assault':'Assault',
    'legend_specialty_Engineer':'Engineer',
    'legend_specialty_Recon':'Recon',
    'legend_specialty_Support':'Support',
    'Role_Attacker':'Attacker',
    'Role_Defender':'Defender',
}

# %%
final_apex = final_apex.rename(columns=standard_columns)

# %%
columns_to_drop = ['tactical_ability','passive_ability','ultimate_ability']

# %%
final_apex = final_apex.drop(columns=columns_to_drop)

# %% [markdown]
# ##### BF's Turn

# %%
final_df
# Out:
#               Specialist Name         Specialist Special Skill 1  \
# 0   SANTIAGO "DOZER" ESPINOZA             SOB-8 Ballistic Shield
# 1                 JI-SOO PAIK                      EMG-X Scanner
# 2    WIKUS "CASPER" VAN DAELE                   OV-P Recon Drone
# 3            CHARLIE CRAWFORD  Mounted Vulcan Stationary Minigun
# 4                RASHEED ZAIN           XM370A Airburst Launcher
# 5               CAMILA BLASCO             X6-Infiltration Device
# 6     PYOTR "BORIS" GUSKOVSKY                   SG-36 Sentry Gun
# 7                 MARIA FALCK                 S21 Syrette Pistol
# 8   CONSTANTIN "ANGEL" ANGHEL                      Loadout Crate
# 9                   NAVIN RAO                Cyber Warfare Suite
# 10                EWELINA LIS                           G-84 TGM
# 11      KIMBLE “IRISH” GRAVES               Fortification System
# 12             WEBSTER MACKAY                     Grappling Hook
# ...

# %%
standard_columns = {
    'Specialist Name':'name',
    'Specialist Specialty_ASSAULT':'Assault',
    'Specialist Specialty_ENGINEER':'Engineer',
    'Specialist Specialty_RECON':'Recon',
    'Specialist Specialty_SUPPORT':'Support',
    'Role_Attacker':'Attacker',
    'Role_Defender':'Defender',
}

# %%
final_df = final_df.rename(columns=standard_columns)

# %%
columns_to_drop = ['Specialist Special Skill 1','Specialist Special Skill 2']

# %%
final_df = final_df.drop(columns=columns_to_drop)

# %% [markdown]
# ##### Standarized

# %%
final_apex
# Out:
#           name  Assault  Engineer  Recon  Support  Attacker  Defender  \
# 0    BANGALORE     True     False  False    False      True     False
# 1         LOBA    False     False  False     True     False      True
# 2     LIFELINE    False     False  False     True     False      True
# 3   PATHFINDER     True     False  False    False      True     False
# 4   BLOODHOUND    False     False   True    False     False      True
# 5      HORIZON     True     False  False    False      True     False
# 6   MAD MAGGIE     True     False  False    False      True     False
# 7         FUSE     True     False  False    False      True     False
# 8      RAMPART    False      True  False    False     False      True
# 9      WATTSON    False      True  False    False     False      True
# 10   BALLISTIC     True     False  False    False      True     False
# 11        SEER    False     False   True    False     False      True
# ...

# %%
final_df
# Out:
#                          name  Assault  Engineer  Recon  Support  Attacker  \
# 0   SANTIAGO "DOZER" ESPINOZA     True     False  False    False      True
# 1                 JI-SOO PAIK    False     False   True    False      True
# 2    WIKUS "CASPER" VAN DAELE    False     False   True    False      True
# 3            CHARLIE CRAWFORD    False      True  False    False     False
# 4                RASHEED ZAIN     True     False  False    False      True
# 5               CAMILA BLASCO    False     False   True    False      True
# 6     PYOTR "BORIS" GUSKOVSKY    False      True  False    False     False
# 7                 MARIA FALCK    False     False  False     True     False
# 8   CONSTANTIN "ANGEL" ANGHEL    False     False  False     True     False
# 9                   NAVIN RAO    False     False   True    False      True
# 10                EWELINA LIS    False      True  False    False     False
# ...

# %%
apex_bf2042 = pd.concat([final_df, final_apex]).reset_index()

# %%
apex_bf2042.drop(['index'],axis=1,inplace=True)

# %%
apex_bf2042
# Out:
#                          name  Assault  Engineer  Recon  Support  Attacker  \
# 0   SANTIAGO "DOZER" ESPINOZA     True     False  False    False      True
# 1                 JI-SOO PAIK    False     False   True    False      True
# 2    WIKUS "CASPER" VAN DAELE    False     False   True    False      True
# 3            CHARLIE CRAWFORD    False      True  False    False     False
# 4                RASHEED ZAIN     True     False  False    False      True
# 5               CAMILA BLASCO    False     False   True    False      True
# 6     PYOTR "BORIS" GUSKOVSKY    False      True  False    False     False
# 7                 MARIA FALCK    False     False  False     True     False
# 8   CONSTANTIN "ANGEL" ANGHEL    False     False  False     True     False
# 9                   NAVIN RAO    False     False   True    False      True
# 10                EWELINA LIS    False      True  False    False     False
# ...

# %% [markdown]
# ### Model Training with BF2042 & APEX LEGENDS

# %%
hybrid_recommender = apex_bf2042[['Assault','Engineer','Recon','Support','Attacker','Defender','Difficulty_1','Difficulty_2','Difficulty_3']]

# %%
scaler = StandardScaler()
xscaled = scaler.fit_transform(hybrid_recommender)

# %%
to_predict = hybrid_recommender.iloc[[13]]

# %%
to_predict_scaled = scaler.transform(to_predict)

# %%
pd.DataFrame(cdist(xscaled,to_predict_scaled),index=apex_bf2042['name'],columns=['distance']).sort_values('distance').head(10)
# Out:
#                            distance
# name
# SANTIAGO "DOZER" ESPINOZA  0.000000
# BALLISTIC                  0.000000
# RASHEED ZAIN               0.000000
# FUSE                       0.000000
# OCTANE                     0.000000
# BANGALORE                  0.000000
# EMMA "SUNDANCE" ROSIER     0.000000
# WEBSTER MACKAY             0.000000
# VALKYRIE                   2.923243
# REVENANT                   2.923243

# %% [markdown]
# This is nice but I would like to know when is it Apex and when is it Battlefield.
